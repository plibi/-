# %% [markdown]
# ----
# # **0. Install Library**
# ----

# %%
# 라이브러리 설치
# !pip install tqdm
# !pip install konlpy

# konlpy, Mecab 설치
# Reference: https://teddylee777.github.io/colab/colab-mecab
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash

# %% [markdown]
# ----
# # **1. Data Cleaning**
# ----
#  - 결측치 확인 => 제거
#  - 중복 리뷰 확인 => 제거

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %%
# 데이터 로드
genre = '드라마'
PATH = '/content/drive/MyDrive/final-project/data'
df = pd.read_csv(PATH + f'/movie_crawling_{genre}.csv', index_col=0)
df.head()
# Out:
#   genre movie_name  score                                             review
# 0   드라마       그린 북     10  폭설내리는밤 경찰이 두번째로 주인공이 몰고가는 차를 세웠을때 우린 경찰의 대사나 행...
# 1   드라마       그린 북     10  우리가 말모이와 스윙키즈처럼 중요한 역사적 소재에 빚지고도 허구의 신파 한가득 버무...
# 2   드라마       그린 북     10  하.. 이런 영화가 상영관수, 상영시간을 많이 늘려야 되는데.. 진짜 예고편만 화려...
# 3   드라마       그린 북     10                          보고나면 KFC 치킨이 존나 떙기는 영화임..
# 4   드라마       그린 북     10                                 빗속 셜리의 대사는 소름이 끼쳤다

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 816159 entries, 0 to 816158
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   genre       816159 non-null  object
#  1   movie_name  816159 non-null  object
#  2   score       816159 non-null  int64
#  3   review      805090 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 31.1+ MB

# %%
# 결측치 확인
# => 1202개(판타지)
# => 11069(드라마)
df.isna().sum()
# Out:
# genre             0
# movie_name        0
# score             0
# review        11069
# dtype: int64

# %%
# 결측치 리뷰 확인
df[df['review'].isna()].head(10)
# Out:
#      genre movie_name  score review
# 443    드라마       그린 북     10    NaN
# 1399   드라마       가버나움     10    NaN
# 1962   드라마         원더     10    NaN
# 1986   드라마         원더     10    NaN
# 2008   드라마         원더     10    NaN
# 2011   드라마         원더     10    NaN
# 2013   드라마         원더     10    NaN
# 2042   드라마         원더     10    NaN
# 2119   드라마         원더     10    NaN
# 2120   드라마         원더      8    NaN

# %%
# 결측치 제거
df = df.dropna()

# %%
# 중복되는 리뷰 확인
# => 10519개(판타지)
# => 151014개(드라마)
duplication_check = df.duplicated(['review'])
duplication_check.sum()
# Out:
# 151014

# %%
# 중복데이터 확인
dup = df[duplication_check == 1]
dup.sample(10)
# Out:
#        genre   movie_name  score  \
# 387603   드라마  성실한 나라의 앨리스      8
# 642466   드라마          풀잎들      5
# 218      드라마         그린 북      8
# 382275   드라마          바이스      8
# 804855   드라마         상류사회      6
# 718092   드라마       대장 김창수     10
# 708445   드라마    신은 죽지 않았다      7
# 426999   드라마         런어웨이      6
# 651424   드라마        튤립 피버     10
# 730879   드라마          해안선      1
#
#                                                    review
# 387603                                                관람객
# 642466                                                관람객
# 218                                                   관람객
# 382275                                                관람객
# 804855                                                관람객
# 718092                                                관람객
# 708445                                                관람객
# 426999  존쿠삭/레이첼와이즈가 메인플롯인데 진해크만과 더스틴호프만 쪽 이야기도 하려다보니 중...
# 651424                                                관람객
# 730879             해안선 영화 기대하고 봤는데 초반엔 좀 괜찮드만 욕나오네 1점도아깝다

# %%
# 유니크한 중복데이터 확인
print(len(dup['review'].unique()))
print(dup['review'].unique()[:10])
# Out:
# 5826
# ['관람객' '스포일러가 포함된 감상평입니다. 감상평 보기' '많은 사람들이 꼭 봤으면 하는 영화'
#  '"힘겨운 싸움을 하는 모든 이들에게 친절하라."' '마음이 따뜻해지는 영화' 'I miss you'
#  '가상의 히어로가 아니라, 진짜 인도의 영웅 이야기. 영화 런타임 긴데 지루하지 않고 재밌습니다' '당갈당갈~ 당갈당갈~'
#  '진짜 쩐다... 내생의 최고의 영화엿음..' '안 보면 아쉬운 영화 꼭 한 번쯤 봤으면 좋겠다']

# %%
# 중복 제거
# 데이터 76553개(판타지), 654076(드라마)
df = df.drop_duplicates(['review'])
len(df)
# Out:
# 654076

# %% [markdown]
# ----
# # **2. Data Preprocessing**
# ----
#  - 리뷰에서 키워드가 될 수 있는 **명사만 추출**
#  - 형태소 분석기(**Okt**, **Mecab**) 비교
#  - **Mecab** 사용
#     - 매우 빠른 실행속도 (65만개 51분 43초(Okt) VS 1분 23초(Mecab))
#     - 더 세부적인 품사태깅 (일반명사, 고유명사, 의존명사, 수사 등)
#  - Mecab으로 **일반명사(NNG)**, **고유명사(NNP)**만 추출
#  - 명사추출 후 **불용어 제거**, **1글자 단어** 제거

# %% [markdown]
# ## 분석 성능 비교

# %% [markdown]
# ### **1) 분석 품질**

# %%
# 형태소 분석기 이용해 명사만 뽑아내는 과정
# 형태소 분석기는 Mecab 사용 (okt, kkma, Komoran 등등 존재)
from konlpy.tag import Okt, Mecab

okt = Okt()
mecab = Mecab()

# %%
# 134, 64
okt.pos(df['review'][64])
# Out:
# [('최근', 'Noun'),
#  ('에', 'Josa'),
#  ('본', 'Verb'),
#  ('영화', 'Noun'),
#  ('중', 'Noun'),
#  ('최고다', 'Noun'),
#  ('.', 'Punctuation'),
#  ('난', 'Noun'),
#  ('이런', 'Adjective'),
#  ('영화', 'Noun'),
#  ('가', 'Josa'),
#  ('좋더라', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('특히', 'Adverb'),
#  ('둘', 'Noun'),
#  ('의', 'Josa'),
#  ('우정은', 'Noun'),
#  ('빛났다', 'Verb'),
#  ('.', 'Punctuation')]

# %%
# NNG:일반명사, NNP: 고유명사, NNB: 의존명사, NR: 수사, MAG: 일반부사
mecab.pos(df['review'][64])
# Out:
# [('최근', 'NNG'),
#  ('에', 'JKB'),
#  ('본', 'VV+ETM'),
#  ('영화', 'NNG'),
#  ('중', 'NNB'),
#  ('최고', 'NNG'),
#  ('다', 'VCP+EF'),
#  ('.', 'SF'),
#  ('난', 'NP+JX'),
#  ('이런', 'MM'),
#  ('영화', 'NNG'),
#  ('가', 'JKS'),
#  ('좋', 'VA'),
#  ('더라', 'EF'),
#  ('.', 'SF'),
#  ('특히', 'MAG'),
#  ('둘', 'NR'),
#  ('의', 'JKG'),
#  ('우정', 'NNG'),
#  ('은', 'JX'),
#  ('빛났', 'VV+EP'),
#  ('다', 'EF'),
#  ('.', 'SF')]

# %% [markdown]
# #### **Okt normalizing 테스트**

# %%
# 문장 정규화 테스트
# okt.normalize 사용
review_list = df['review'].tolist()
n_review = []
for review in tqdm(review_list):
    result = okt.normalize(review)
    n_review.append(result)
n_review[:7]
# Out:
#   0%|          | 0/654076 [00:00<?, ?it/s]
# ['폭설내리는밤 경찰이 두번째로 주인공이 몰고가는 차를 세웠을때 우린 경찰의 대사나 행동을 예측했을 것이다. 하지만 그 예측 자체가 영화보는내내 우리에게 생긴 편견임을 알고 뒤통수를 맞은 느낌이었다!',
#  "우리가 말모이와 스윙키즈처럼 중요한 역사적 소재에 빚지고도 허구의 신파 한가득 버무려놓아 눈물 쥐어짠 걸 의미있는 영화라 자아도취해 있을 동안, 헐리우드는 실화 소재로 이런 '작품'을 배출하는 경지에 ...",
#  '하.. 이런 영화가 상영관수, 상영시간을 많이 늘려야 되는데.. 진짜 예고편만 화려한 거품영화만 너무 독차지 하고있으니..아쉽',
#  '보고나면 KFC 치킨이 존나 떙기는 영화임..',
#  '빗속 셜리의 대사는 소름이 끼쳤다',
#  '정말 많은 여운이 남은 영화네요. 꼭 봐야 할 영화입니다',
#  '비고 모텐슨 형님 반지의 제왕에서 꽃미남 왕으로 열연하던게 엊그제 같은데 중년 마초역도 멋있잖아..']

# %%
# 정규화 전, 후 차이 확인
# 이건 => 이것은
# 재밋엇어 => 재밌엇어
# 반복되는 문자 처리
# 큰차이 X

cnt = 0
for n, (i, j) in enumerate(zip(review_list, n_review)):
    if n == 1000:
        break
    if i != j:
        cnt += 1
        print(i)
        print(j)
print(cnt)
# Out:
# 인생영화 하나 나왔네요!! 강추합니당
# 인생영화 하나 나왔네요!! 강추합니다
# 두 남자의 연기, 밀도 있는 스토리, 올드팝과 재즈, 중간중간 위트까지.. 크리스마스때 봤음 더 좋을 영화! 최고임다!
# 두 남자의 연기, 밀도 있는 스토리, 올드팝과 재즈, 중간중간 위트까지.. 크리스마스때 봤음 더 좋을 영화! 최고입니다!
# 댓글 단 모든분들께 감사드립니다당신들 덕분에 이 영화를 보았고 영화 덕분에삶의 진정한 가치가 뭔지 배웁니다
# 댓글 단 모든분들께 감사드립니다당신들 덕분에 이 영화를 보았고 영화 덕분에삶의 진정한 가치가 뭐인지 배웁니다
# 한국영화에 밀려 심야영화로 간신히 봄 도대체 뭥미
# 한국영화에 밀려 심야영화로 간신히 봄 도대체 뭐임
# 오늘보고왔는뎁 넘좋았어요 보고오길잘했다는 생각이드네요 실화였다니이이이 아정말재미이어고 좋아어요 꼭보세용ㅎㅎ^^대박나세용^^♥♥
# 오늘보고왔는뎁 넘좋았어요 보고오길잘했다는 생각이드네요 실화였다니이이이 아정말재미이어고 좋아어요 꼭보세요ㅎㅎ^^대박나세요^^♥♥
# 진짜 정말 멋잇다 이건 또 보고싶다
# 진짜 정말 멋잇다 이것은 또 보고싶다
# 마지막 나의 입을 ^ㅡㅡㅡㅡ ^ 이렇게 만들어주고 끝났다
# 마지막 나의 입을 ^ㅡㅡㅡ ^ 이렇게 만들어주고 끝났다
# 피아노 치는거 합성임? 진짜 치는거임?난 웨슬리 스나입스 형님인줄 알았음.이게 작품상받고 왜논란 됐나몰라.로마 보다 백배 재밋음
# 피아노 치는거 합성임? 진짜 치는거임?난 웨슬리 스나입스 형님인줄 알았음.이게 작품상받고 왜논란 됐나몰라.로마 보다 백배 재밌음
# 정말 재밋네요 왠만하면 귀찬아서 평점 안쓰는데소소하게 재밌기도 하면서 따듯하고...내용에 교훈도 많으면서마치 잠깐 어디 여행다녀온 느낌입니다제가 본영화중에 손에 꼽아요...담에 또봐야지...그린북 최고
# 정말 재밌네요 왠만하면 귀찬아서 평점 안쓰는데소소하게 재밌기도 하면서 따듯하고...내용에 교훈도 많으면서마치 잠깐 어디 여행다녀온 느낌입니다제가 본영화중에 손에 꼽아요...담에 또봐야지...그린북 최고
# 정말 이런 영화가 많이 떠야하는 건데... 보는 내내 마음 한 쪽이 시리기도 했다가 따뜻해지는 영화. 다시 보고 싶네요.
# 정말 이런 영화가 많이 떠야하는 거인데... 보는 내내 마음 한 쪽이 시리기도 했다가 따뜻해지는 영화. 다시 보고 싶네요.
# 먼가 말로할수없는 기쁨?행복함이 있는 영화네요. 최고에요 정말
# 무엇인가 말로할수없는 기쁨?행복함이 있는 영화네요. 최고에요 정말
# KFC 존맛탱ㅋㅋㅋㅋ
# KFC 존맛탱ㅋㅋㅋ
# 값싼 동정은 내려놓고 무얼 할 수 있을지 짧게 고민하고 행동으로 옮겨야겠다..나의 고통은 사치였고 난 개돼지처럼 살았다..
# 값싼 동정은 내려놓고 무엇을 할 수 있을지 짧게 고민하고 행동으로 옮겨야겠다..나의 고통은 사치였고 난 개돼지처럼 살았다..
# 이건 영화가아니다!! 리얼이다
# 이것은 영화가아니다!! 리얼이다
# 배우지 못하고 불행이 뭔지 모르고 행복은 상대적인것...새삼 우울증은 진짜 부자병이라는 생각이 든다
# 배우지 못하고 불행이 뭐인지 모르고 행복은 상대적인것...새삼 우울증은 진짜 부자병이라는 생각이 든다
# 15

# %% [markdown]
# ### **2) 소요시간**

# %%
# 51분 43초
okt_nouns = df['review'].apply(okt.nouns)
okt_nouns[:10]

# %%
# 1분 23초
# Mecab으로 명사 추출

# 문장을 입력받아 품사태깅 후 NNG와 NNP만 추출하는 함수
def NNGNNP(sentence):
    nouns = []
    result = mecab.pos(sentence)
    for element in result:
        if element[1] == 'NNG' or element[1] == 'NNP':
            nouns.append(element[0])
    return nouns


# NNG, NNP 명사만 추출한 Review라는 새로운 col 생성
df['Review'] = ''
df['Review'] = df['review'].apply(NNGNNP)
df.head()
# Out:
#   genre movie_name  score                                             review  \
# 0   드라마       그린 북     10  폭설내리는밤 경찰이 두번째로 주인공이 몰고가는 차를 세웠을때 우린 경찰의 대사나 행...
# 1   드라마       그린 북     10  우리가 말모이와 스윙키즈처럼 중요한 역사적 소재에 빚지고도 허구의 신파 한가득 버무...
# 2   드라마       그린 북     10  하.. 이런 영화가 상영관수, 상영시간을 많이 늘려야 되는데.. 진짜 예고편만 화려...
# 3   드라마       그린 북     10                          보고나면 KFC 치킨이 존나 떙기는 영화임..
# 4   드라마       그린 북     10                                 빗속 셜리의 대사는 소름이 끼쳤다
#
#                                               Review
# 0  [폭설, 밤, 경찰, 주인공, 차, 때, 경찰, 대사, 행동, 예측, 예측, 자체,...
# 1  [말모이, 스윙, 키즈, 중요, 역사, 소재, 허구, 신파, 눈물, 의미, 영화, ...
# 2             [영화, 상영관, 수, 상영, 시간, 예고편, 거품, 영화, 독차지]
# 3                                           [치킨, 영화]
# 4                                   [빗속, 셜리, 대사, 소름]

# %% [markdown]
# ## **불용어 제거**
#  - **불용어 사전** 등록 단어 제거
#     - 자주 등장하는, 상위 빈도수의 영화와 관련된 보편적인 단어
#     - 부사, 형용사적 의미를 갖는 명사
#     - 나라이름
#  - **1글자 단어** 제거

# %%
# 불용어 사전
# 1. 자주 등장하는, 상위 빈도수의 영화와 관련된 보편적인 단어: 영화제목들, 영화, 관람객, 생각, 평점, 하나, 작품, 아이 등
# 2. 부사, 형용사적 의미를 갖는 명사: 정말, 진짜, 최고, 그냥 등등
# 3. 국가명

# 불용어 사전 정의
stopword = ['정말', '진짜', '최고', '그냥', '마지막', '다시', '완전', '정도', '역시', '처음', '지금', '이건', '별로', '때문', '뭔가', '가장', '조금', '제일',
            '영화', '관람객', '생각', '평점', '하나', '작품', '아이', '최악', '일본', '미국', '중국', '호주', '프랑스', '한국', '인도']

# 영화 타이틀 추가
for title in df['movie_name'].unique().tolist():
    stopword.append(title)

# 불용어 사전 확인
print(len(stopword))
print(stopword)
# Out:
# 1148
# ['정말', '진짜', '최고', '그냥', '마지막', '다시', '완전', '정도', '역시', '처음', '지금', '이건', '별로', '때문', '뭔가', '가장', '조금', '제일', '영화', '관람객', '생각', '평점', '하나', '작품', '아이', '최악', '일본', '미국', '중국', '호주', '프랑스', '한국', '인도', '그린 북', '가버나움', '원더', '아일라', '먼 훗날 우리', '당갈', '쇼생크 탈출', '덕구', '보헤미안 랩소디', '포레스트 검프', '위대한 쇼맨', '인생은 아름다워', '헬프', '캐스트 어웨이', '히든 피겨스', '쉰들러 리스트', '집으로...', '죽은 시인의 사회', '아이 캔 스피크', '동주', '여인의 향기', '미스 슬로운', '굿바이 마이 프랜드', '굿 윌 헌팅', '지상의 별처럼', '아마데우스', '자산어보', '빌리 엘리어트', '두 교황', '그대를 사랑합니다', '아이 엠 샘', '피아니스트', '시네마 천국', '달링', '소원', '블라인드 사이드', '패왕별희 디 오리지널', '뷰티풀 투모로우', '우리들의 일그러진 영웅', '코러스', '8월의 크리스마스', '일급 살인', '허스토리', '내 이름은 칸', '록키', '나, 다니엘 블레이크', '시월애', '언플랜드', '인생', '우리들', '공동경비구역 JSA', '천국의 아이들', '맨발의 꿈', '랜드 오브 마인', '세상에서 가장 아름다운 이별', '바람', '도가니', '온리 더 브레이브', '또 하나의 약속', '피아니스트의 전설', '신데렐라 맨', '투게더', '기적', '뷰티풀 마인드', '광해, 왕이 된 남자', '쿨 러닝', '친정엄마', '미안해요, 리키', '집으로 가는 길', '바람과 함께 사라지다', '타인의 삶', '라이언', '말아톤', '킹콩을 들다', '맨 오브 오너', '파워 오브 원', '1987', '핵소 고지', '벤허', '로미오와 줄리엣', '마지막 황제', '똥파리', '오베라는 남자', '나비 효과', '내 사랑', '특전 유보트', '야쿠자와 가족', '내 어깨 위 고양이, 밥', '어느 가족', '크루엘라', '어메이징 메리', '눈길', '스타 이즈 본', '내겐 너무 소중한 너', '뻐꾸기 둥지 위로 날아간 새', '불량소녀, 너를 응원해!', '파수꾼', '해피 투게더', '킹 오브 프리즘', '헤드윅', '오아시스', '분노의 역류', '체인질링', '코치 카터', '그래도 내가 하지 않았어', '제리 맥과이어', '일 포스티노', '바울', '톰보이', '귀향', '파 앤드 어웨이', '길버트 그레이프', '설리: 허드슨강의 기적', '아름다운 세상을 위하여', '코다', '말모이', '할머니는 일학년', '아이', '국가대표', '스텝 업 3D', '철가방 우수氏', '러브레터', '봄날은 간다', '아버지의 이름으로', '호로비츠를 위하여', '와이키키 브라더스', '스틸 라이프', '스탠 바이 미', '다키스트 아워', '증인', '웨딩 드레스', '미쓰백', '용서받지 못한 자', '러브 오브 시베리아', '샤인', '파도가 지나간 자리', '글루미 선데이', '호텔 르완다', '언포기버블', '에린 브로코비치', '마이 걸', '티벳에서의 7년', '책상 서랍 속의 동화', '밀리언 달러 베이비', '쓰리 세컨즈', '아이덴티티', '어린 의뢰인', '블랙', '얼라이브', '누들', '서프러제트', '식스 센스', '미스비헤이비어', '아홉살 인생', '하모니', '불멸의 연인', '월플라워', '콜드 마운틴', '왕의 남자', '레이', '올드보이', '굿바이', '타오르는 여인의 초상', '비긴 어게인', '캡틴 필립스', '퍼펙트 월드', '스윗 프랑세즈', '크로싱', '세컨핸드 라이온스', '택시운전사', '십계', '로마', '사랑의 선물', '슈퍼스타 감사용', '싱 스트리트', '말레나', '연평해전', '빅 피쉬', '파리넬리', '산이 울다', '툴리', '마이 시스터즈 키퍼', '국제시장', '박하사탕', '델마와 루이스', '독수리 에디', '홈', '세상을 바꾼 변호인', '안녕, 나의 소울메이트', '룸', '개를 훔치는 완벽한 방법', '어거스트 러쉬', '변호인', 'K-19 위도우메이커', '더 파더', '휘트니', '씨 인사이드', '아메리칸 뷰티', '파이브 피트', '골!', '조제, 호랑이 그리고 물고기들', '코알라', '원스', '스플릿', '레인 오버 미', '레인 맨', '루키', '더 헌트', '내 마음의 풍금', '더 리더: 책 읽어주는 남자', '흐르는 강물처럼', '태양의 노래', '담보', '거인', '5일의 마중', '미션', '오만과 편견', '파인딩 포레스터', '나의 특별한 형제', '남매의 여름밤', '리틀 보이', '매디슨 카운티의 다리', '시', '피아노의 숲', '키즈 리턴', '대니쉬 걸', '행복을 찾아서', '주먹이 운다', '제8요일', '퍼펙트 게임', '초콜릿', '비투스', '인어 공주', '스포트라이트', '서치', '초콜렛 도넛', '씨민과 나데르의 별거', '존 큐', '뜨거운 안녕', '호밀밭의 반항아', '소년은 울지 않는다', '여행자', '부러진 화살', '중경삼림', '48미터', '배심원들', '1917', '장수상회', '앙: 단팥 인생 이야기', '서편제', '좋은 친구들', '웰컴 투 동막골', '노다메 칸타빌레 최종악장', '사랑 후에 남겨진 것들', '1급기밀', '아무도 모른다', '그렇게 아버지가 된다', '청원', '드리머', '디태치먼트', '순정', '잔칫날', '델타 보이즈', '각설탕', '우먼 인 골드', '일일시호일', '스왈로우테일 버터플라이', '여배우는 오늘도', '어느 날, 사랑이 걸어왔다', '글러브', '파이터', '무사', '리틀 포레스트', '라스트 미션', '페이스 메이커', '초록물고기', '스탠바이, 웬디', '연인', '크레이지 뷰티풀', '처음 만나는 자유', '믿음의 승부', '트럼보', '패트리어트 - 늪 속의 여우', '틱, 틱... 붐!', '작은 아씨들', '미라클 벨리에', '8 마일', '다크 워터스', '계춘할망', '10분', '바스켓볼 다이어리', '고양이를 부탁해', '화양연화', '위플래쉬', '탑건', '말죽거리 잔혹사', '스트레이트 아웃 오브 컴턴', '한공주', '레퀴엠', '두레소리', '쓰리 빌보드', '완득이', '죽여주는 여자', '봄 여름 가을 겨울 그리고 봄', '이번 일요일에', '이미테이션 게임', '집오리와 들오리의 코인로커', '달라스 바이어스 클럽', '크게 될 놈', '나우 이즈 굿', '라빠르망', '더 포스트', '데이비드 게일', '출국', '비포 선셋', '김씨 표류기', '나의 사랑, 그리스', '찬실이는 복도 많지', '패트리어트 데이', '가장 따뜻한 색, 블루', '박사가 사랑한 수식', '란도리', '인 어 베러 월드', '아홉 스님', '워크 투 리멤버', '도그빌', '애자', '대니 콜린스', '벌새', '사랑은 비가 갠 뒤처럼', '고야의 유령', '몬태나', '봄', '본 투 비 블루', '오페라의 유령', '더 페이버릿: 여왕의 여자', '네버랜드를 찾아서', '어드리프트:우리가 함께한 바다', '빨간 구두', '현기증', '채비', '바닷마을 다이어리', '보이후드', '브레이킹 던 part2', '스텝 업', '블랙 스완', '러덜리스', '맨체스터 바이 더 씨', '언노운 우먼', '공기살인', '진짜로 일어날지도 몰라 기적', '미운 오리 새끼', '히노키오', '남자가 사랑할 때', '아모레스 페로스', '잉글리쉬 페이션트', '부르고뉴, 와인에서 찾은 인생', '버스, 정류장', '버팔로 66', '엘 시크레토: 비밀의 눈동자', '우리집', '데이라잇', '그을린 사랑', '우리들의 행복한 시간', '허브', '고', '해가 서쪽에서 뜬다면', '취화선', '동사서독', '더 박스', '마미', '스노든', '내 생애 가장 아름다운 일주일', '콜레트',  ...

# %%
# 불용어 제거 함수
def RemoveStopWord(ls):
    clean_review = []
    for element in ls:
        if len(element) == 1 or element in stopword:
            continue
        clean_review.append(element)
    return clean_review

df['Review'] = df['Review'].apply(RemoveStopWord)
df.head()
# Out:
#   genre movie_name  score                                             review  \
# 0   드라마       그린 북     10  폭설내리는밤 경찰이 두번째로 주인공이 몰고가는 차를 세웠을때 우린 경찰의 대사나 행...
# 1   드라마       그린 북     10  우리가 말모이와 스윙키즈처럼 중요한 역사적 소재에 빚지고도 허구의 신파 한가득 버무...
# 2   드라마       그린 북     10  하.. 이런 영화가 상영관수, 상영시간을 많이 늘려야 되는데.. 진짜 예고편만 화려...
# 3   드라마       그린 북     10                          보고나면 KFC 치킨이 존나 떙기는 영화임..
# 4   드라마       그린 북     10                                 빗속 셜리의 대사는 소름이 끼쳤다
#
#                                               Review
# 0  [폭설, 경찰, 주인공, 경찰, 대사, 행동, 예측, 예측, 자체, 편견, 뒤통수,...
# 1  [스윙, 키즈, 중요, 역사, 소재, 허구, 신파, 눈물, 의미, 자아, 동안, 헐...
# 2                        [상영관, 상영, 시간, 예고편, 거품, 독차지]
# 3                                               [치킨]
# 4                                   [빗속, 셜리, 대사, 소름]

# %%
# 전처리 후 빈 리뷰는 제거
df = df[df['Review'].apply(len) != 0]
df.head()
# Out:
#   genre movie_name  score                                             review  \
# 0   드라마       그린 북     10  폭설내리는밤 경찰이 두번째로 주인공이 몰고가는 차를 세웠을때 우린 경찰의 대사나 행...
# 1   드라마       그린 북     10  우리가 말모이와 스윙키즈처럼 중요한 역사적 소재에 빚지고도 허구의 신파 한가득 버무...
# 2   드라마       그린 북     10  하.. 이런 영화가 상영관수, 상영시간을 많이 늘려야 되는데.. 진짜 예고편만 화려...
# 3   드라마       그린 북     10                          보고나면 KFC 치킨이 존나 떙기는 영화임..
# 4   드라마       그린 북     10                                 빗속 셜리의 대사는 소름이 끼쳤다
#
#                                               Review
# 0  [폭설, 경찰, 주인공, 경찰, 대사, 행동, 예측, 예측, 자체, 편견, 뒤통수,...
# 1  [스윙, 키즈, 중요, 역사, 소재, 허구, 신파, 눈물, 의미, 자아, 동안, 헐...
# 2                        [상영관, 상영, 시간, 예고편, 거품, 독차지]
# 3                                               [치킨]
# 4                                   [빗속, 셜리, 대사, 소름]

# %%
# 인덱스 초기화
df = df.reset_index()
df = df.drop(['index'], axis=1)

# %%
df.head(10)
# Out:
#   genre movie_name  score                                             review  \
# 0   드라마       그린 북     10  폭설내리는밤 경찰이 두번째로 주인공이 몰고가는 차를 세웠을때 우린 경찰의 대사나 행...
# 1   드라마       그린 북     10  우리가 말모이와 스윙키즈처럼 중요한 역사적 소재에 빚지고도 허구의 신파 한가득 버무...
# 2   드라마       그린 북     10  하.. 이런 영화가 상영관수, 상영시간을 많이 늘려야 되는데.. 진짜 예고편만 화려...
# 3   드라마       그린 북     10                          보고나면 KFC 치킨이 존나 떙기는 영화임..
# 4   드라마       그린 북     10                                 빗속 셜리의 대사는 소름이 끼쳤다
# 5   드라마       그린 북     10                    정말 많은 여운이 남은 영화네요. 꼭 봐야 할 영화입니다
# 6   드라마       그린 북     10  비고 모텐슨 형님 반지의 제왕에서 꽃미남 왕으로 열연하던게 엊그제 같은데 중년 마초...
# 7   드라마       그린 북     10              2019년 아카데미 작품상은 그린 북, 남우조연상은 마허샬라 알리!
# 8   드라마       그린 북     10                   경찰관에게 메리크리스마스 하는 장면..너무 조하 따뜻해..
# 9   드라마       그린 북     10  '우정' 과 '인종 차별' 모두를 아우르는 뛰어난 소재에 뒷받침하는 두 배우들의 뛰...
#
#                                               Review
# 0  [폭설, 경찰, 주인공, 경찰, 대사, 행동, 예측, 예측, 자체, 편견, 뒤통수,...
# 1  [스윙, 키즈, 중요, 역사, 소재, 허구, 신파, 눈물, 의미, 자아, 동안, 헐...
# 2                        [상영관, 상영, 시간, 예고편, 거품, 독차지]
# 3                                               [치킨]
# 4                                   [빗속, 셜리, 대사, 소름]
# 5                                               [여운]
# 6                 [비고, 모텐슨, 반지, 제왕, 꽃미남, 열연, 중년, 마초]
# 7                   [아카데미, 작품상, 남우, 조연상, 마허, 샬라, 알리]
# 8                           [경찰관, 메리, 크리스마스, 장면, 조하]
# 9  [우정, 인종, 차별, 모두, 소재, 뒷받침, 배우, 심리, 변화, 연기, 디테일,...

# %% [markdown]
# ----
# # **3. Save**
# ----

# %%
# pickle로 data를 list 형태로 저장 (pickle을 이용하면 데이터 타입도 유지하면서 저장가능, Review:list타입)
import pickle

PATH = '/content/drive/MyDrive/final-project/processed_data/data/'
file_name = f'preprocessing_{genre}_0513_unique.pkl'
with open(PATH + file_name, 'wb') as f:
    pickle.dump(df, f, protocol=4)

# %% [markdown]
# ### Save Test

# %%
# pickle로 저장한 데이터 불러오기
import pickle

genre = '판타지'

with open(PATH + f'/movie_{genre}_0513.pkl', 'rb') as f:
    data = pickle.load(f)

data.head()
# Out:
#   genre     movie_name  score  \
# 0   판타지  반지의 제왕: 왕의 귀환     10
# 1   판타지  반지의 제왕: 왕의 귀환     10
# 2   판타지  반지의 제왕: 왕의 귀환     10
# 3   판타지  반지의 제왕: 왕의 귀환     10
# 4   판타지  반지의 제왕: 왕의 귀환     10
#
#                                               review  \
# 0                 내가 극장에서 이 영화를 봣다는게 너무 자랑스럽고 감동적입니다
# 1                  현존하는 최고의 판타지영화... 퀄리티가 절대 애들용이 아님
# 2  왜 이영화를이제서야봤는지ㅠㅠ 일편부터연달아보는데 재밌다가도 시간가는게너무안타까웠음ㅠ...
# 3                               몇년이 지난 영화인데도 소름돋는영화.
# 4                  반지의제왕 안본사람은 있어도한번본 사람은 없다는게 사실인가요
#
#                          Review
# 0                  [극장, 자랑, 감동]
# 1                [현존, 판타지, 퀄리티]
# 2  [시간, 반지, 제왕, 명작, 가슴, 며칠, 행복]
# 3                          [소름]
# 4          [반지, 제왕, 사람, 사람, 사실]

# %%
# Review 데이터 타입 list 확인
print(data['Review'][0])
type(data['Review'][0])
# Out:
# ['극장', '자랑', '감동']
# list
